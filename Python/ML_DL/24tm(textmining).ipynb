# %% [markdown]
# # 24 tm

# %% [markdown]
# ## 텍스트 마이닝
# * 자연어로 구성된 '비정형 데이터'에서 패턴 또는 관계를 추출하여
#   의미 있는 정보를 찾아내는 기법들을 의미
# * 활용분야
#     + 유사 단어들(또는 문서들)간의 군집 분석
#     + 연관 단어의 추출 또는 단어 네트워크 분석
#     + 감성 분석
#     + 주요 키워드별 빈도에 따른 시각화

# %% [markdown]
# ## 파이썬 기반 텍스트 분석 패키지
# * NLTK, KoNLPy : 영어권/한국어 형태소 분석기
# * Gensim : 텍스트요약에 두각을 나타냄
#   word2vec 기능도 구현되어 있음
# * SpaCy : 최근에 주목받는 NLP 패키지

# %% [markdown]
# ## NLTK
# * 교육용으로 개발된 자연어 처리 및 분석 패키지
# * www.nltk.org
# * pip install nltk

# %%
# pip --trusted-host pypi.org --trusted-host files.pythonhosted.org install nltk

# %% [markdown]
# ## English NLP

# %%
import nltk

# %%
# nltk 내장 영어 말뭉치corpus
# corpus : 분석을 위해 추출된 텍스트
nltk.download('book', quiet=True)
# Out:
# True

# %%
# 말뭉치 확인
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
texts()
# Out:
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
sents()
# Out:
# sent1: Call me Ishmael .
# sent2: The family of Dashwood had long been settled in Sussex .
# sent3: In the beginning God created the heaven and the earth .
# sent4: Fellow - Citizens of the Senate and of the House of Representatives :
# sent5: I have a problem with people PMing me to lol JOIN
# sent6: SCENE 1 : [ wind ] [ clop clop clop ] KING ARTHUR : Whoa there !
# sent7: Pierre Vinken , 61 years old , will join the board as a nonexecutive director Nov. 29 .
# sent8: 25 SEXY MALE , seeks attrac older single lady , for discreet encounters .
# sent9: THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of sunset .

# %%
len(text1)
# Out:
# 260819

# %%
text1[:10]
# Out:
# ['[',
#  'Moby',
#  'Dick',
#  'by',
#  'Herman',
#  'Melville',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.']

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
# 저작권이 말소된 문학작품
# 일명, 구텐베르그 말뭉치 확인
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
# 햄릿을 불러서 출력
doc = nltk.corpus.gutenberg.raw('shakespeare-hamlet.txt')
doc[:300]
# Out:
# "[The Tragedie of Hamlet by William Shakespeare 1599]\n\n\nActus Primus. Scoena Prima.\n\nEnter Barnardo and Francisco two Centinels.\n\n  Barnardo. Who's there?\n  Fran. Nay answer me: Stand & vnfold\nyour selfe\n\n   Bar. Long liue the King\n\n   Fran. Barnardo?\n  Bar. He\n\n   Fran. You come most carefully vpon "

# %% [markdown]
# ## 텍스트 토큰화
# * 문장 토큰화 : 문서에서 문장을 분리
# * 단어 토큰화 : 문장에서 단어를 분리

# %%
# 토큰화를 위한 패키지 설치
from nltk import sent_tokenize
from nltk import word_tokenize

# %%
# 토큰화에 필요한 데이터 다운로드
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/hadoop/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text_sample = 'The Matrix is everywhere its all around us, here even in this room. \
               You can see it out your window or on your television. \
               You feel it when you go to work, or go to church or pay your taxes.'

# %%
# 문장 토큰화 : sent_tokenize(문서)
sents = sent_tokenize(text_sample)
sents   # 결과는 리스트로 저장
# Out:
# ['The Matrix is everywhere its all around us, here even in this room.',
#  'You can see it out your window or on your television.',
#  'You feel it when you go to work, or go to church or pay your taxes.']

# %%
# 문장 토큰화 : word_tokenize(문장)
words = word_tokenize(sents[0])
words
# Out:
# ['The',
#  'Matrix',
#  'is',
#  'everywhere',
#  'its',
#  'all',
#  'around',
#  'us',
#  ',',
#  'here',
#  'even',
#  'in',
#  'this',
#  'room',
#  '.']

# %%
# 문장토큰화한 후 단어토큰화 실시
words = []
sents = sent_tokenize(text_sample)
for sent in sents:
    words.append(word_tokenize(sent))

# %%
words[:1]
# Out:
# [['The',
#   'Matrix',
#   'is',
#   'everywhere',
#   'its',
#   'all',
#   'around',
#   'us',
#   ',',
#   'here',
#   'even',
#   'in',
#   'this',
#   'room',
#   '.']]

# %%
len(words)   # 3
# Out:
# 3

# %% [markdown]
# ## 불용어stopword 제거
# * 분석에 큰 의미가 없는 단어를 지칭
# * NLTK상에서는 stopwords 형태로 제공됨
# * 하지만, 제공되는 단어수는 적음

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/hadoop/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.corpus.stopwords.words('english')[:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
# 텍스트 전처리 후 단어 토큰화 실시
stopwords = nltk.corpus.stopwords.words('english')
tokens = []

for wds in words:
    filter_words = []
    for w in wds:
        w = w.lower()   # 단어를 소문자로 변환
        if w not in stopwords:
            filter_words.append(w)
    tokens.append(filter_words)
    
tokens
# Out:
# [['matrix', 'everywhere', 'around', 'us', ',', 'even', 'room', '.'],
#  ['see', 'window', 'television', '.'],
#  ['feel', 'go', 'work', ',', 'go', 'church', 'pay', 'taxes', '.']]

# %% [markdown]
# ## 트럼프 연설문을 이용한 단어 토큰화

# %%
# 파일 읽기
docs = []

with open('data/trump_en.txt') as f:
    docs = f.read()   # 텍스트파일을 통채로 텍스트형태로 읽어옴
    
docs[:100]
# Out:
# 'Assembly Speaker Chung, distinguished members of this Assembly, ladies and gentlemen: Thank you for '

# %%
# 문장/단어 토큰화
import re

sents = sent_tokenize(docs)
sents[:1]

words = []
for s in sents:
    # 알파벳 대소문자를 제외하고 모두 제거
    s = re.sub('[^a-zA-Z]', ' ', s).strip()
    words.append(word_tokenize(s))
words[:1]
# Out:
# [['Assembly',
#   'Speaker',
#   'Chung',
#   'distinguished',
#   'members',
#   'of',
#   'this',
#   'Assembly',
#   'ladies',
#   'and',
#   'gentlemen',
#   'Thank',
#   'you',
#   'for',
#   'the',
#   'extraordinary',
#   'privilege',
#   'to',
#   'speak',
#   'in',
#   'this',
#   'great',
#   'chamber',
#   'and',
#   'to',
#   'address',
#   'your',
#   'people',
#   'on',
#   'behalf',
#   'of',
#   'the',
#   'people',
#   'of',
#   'the',
#   'United',
#   'States',
#   'of',
#   'America']]

# %%
tokens1 = []
for wds in words:
    fwords = []
    for w in wds:
        w = w.lower()
        if w not in stopwords:
            fwords.append(w)
    tokens1.append(fwords)
tokens1[:1]
# Out:
# [['assembly',
#   'speaker',
#   'chung',
#   'distinguished',
#   'members',
#   'assembly',
#   'ladies',
#   'gentlemen',
#   'thank',
#   'extraordinary',
#   'privilege',
#   'speak',
#   'great',
#   'chamber',
#   'address',
#   'people',
#   'behalf',
#   'people',
#   'united',
#   'states',
#   'america']]

# %% [markdown]
# ### 스티브잡스 스탠포드대 졸업축사 단어 토큰화 (stevejobs_en.txt)

# %%
# 파일 읽기
docs = []

with open('data/stevejobs_en.txt') as f:
    docs = f.read()   # 텍스트파일을 통채로 텍스트형태로 읽어옴
    
docs[:100]
# Out:
# 'I am honored to be with you today at your commencement from one of the finest universities in the wo'

# %%
# 문장/단어 토큰화
sents = sent_tokenize(docs)
sents[:1]

words = []
for s in sents:
    s = re.sub('[^a-zA-Z]', ' ', s).strip()
    words.append(word_tokenize(s))
words[:1]
# Out:
# [['I',
#   'am',
#   'honored',
#   'to',
#   'be',
#   'with',
#   'you',
#   'today',
#   'at',
#   'your',
#   'commencement',
#   'from',
#   'one',
#   'of',
#   'the',
#   'finest',
#   'universities',
#   'in',
#   'the',
#   'world']]

# %%
tokens2 = []
for wds in words:
    fwords = []
    for w in wds:
        w = w.lower()
        if w not in stopwords:
            fwords.append(w)
    tokens2.append(fwords)
tokens2[:1]
# Out:
# [['honored',
#   'today',
#   'commencement',
#   'one',
#   'finest',
#   'universities',
#   'world']]

# %% [markdown]
# ## 형태소 분석
# * 의미가 있는 최소의 단위로서 더 이상 분리가 불가능한 가장 작은 의미 요소
# * 주어진 단어 또는 어절을 구성하는 각 형태소를 분리한 후
#   분리된 형태소의 기본형 및 품사 정보를 추출하는 것
# * 문장 > 어절 > 단어 > 어근/접두사/접미사 > 품사
#     + work : 동사/명사
#     + working : working의 원형인 work를 추출 후 동사/명사
#     + 영어의 경우 과거/현재/미래, 단수, 진행형 등에 따라 단어가 변화함
#     + 보조적으로 어근추출stemming이나 원형복원lemmatizing이 필요할 수 있음

# %% [markdown]
# ## 품사태깅POS tagging
# * 단어를 문법적 기능이나 형태, 의미에 따라 구분한 것
# * NLTK에서는 Penn Treebank Tagset을 이용해서 품사태깅을 함
# * NNP, VB, VBP, TO, NN, DT, ADJ

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/hadoop/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk.tag import pos_tag

# %%
# 기존 문장에 대해 품사태깅 실시
tags = pos_tag(tokens[0])
tags   # (RB부사, IN종속전치사, PRP대명사)
# Out:
# [('matrix', 'NN'),
#  ('everywhere', 'RB'),
#  ('around', 'IN'),
#  ('us', 'PRP'),
#  (',', ','),
#  ('even', 'RB'),
#  ('room', 'NN'),
#  ('.', '.')]

# %%
## 분석에 필요한 토큰추출 - 품사가 명사인 토큰을 대상
nouns = []
for t in tokens:
    tags = pos_tag(t)
    NN = [l[0] for l in tags if l[1] == 'NN']
    nouns.append(NN)
nouns
# Out:
# [['matrix', 'room'], ['television'], ['feel', 'work', 'church', 'pay']]

# %% [markdown]
# ## 트럼프 연설문 품사태깅

# %%
nouns1 = []
for t in tokens1:
    tags = pos_tag(t)
    NN = [w[0] for w in tags if w[1] == 'NN']
    nouns1.append(NN)
nouns1[:5]
# Out:
# [['speaker', 'chung', 'privilege', 'speak', 'chamber'],
#  ['time', 'country', 'melania', 'welcome'],
#  ['night', 'president', 'mrs'],
#  ['moon', 'hospitality', 'reception', 'blue', 'house'],
#  ['cooperation',
#   'trade',
#   'relationship',
#   'principle',
#   'fairness',
#   'reciprocity']]

# %% [markdown]
# ## 스티브잡스 스탠포드대 졸업축사 품사태깅

# %%
nouns2 = []
for t in tokens2:
    tags = pos_tag(t)
    NN = [w[0] for w in tags if w[1] == 'NN']
    nouns2.append(NN)
nouns2[:5]
# Out:
# [['today', 'commencement', 'finest', 'world'],
#  ['college'],
#  ['truth', 'college', 'graduation'],
#  ['today', 'tell', 'life'],
#  []]

# %% [markdown]
# ### 단어빈도
# * 텍스트 데이터의 대표단어를 알아볼수 있는 방법
# * 단어별 빈도를 조사해서 알아낸 상위 n개의 단어들을 대표단어를 지정

# %%
from nltk import FreqDist

# %%
# 먼저, 기존단어들이 저장된 2차원 리스트를 1차원으로 바꿈
NNO = []
for ns in nouns:
    for n in ns:
        NNO.append(n)

# %%
# 단어별 빈도 파악
frqwords = FreqDist(NNO)
frqwords
# Out:
# FreqDist({'matrix': 1, 'room': 1, 'television': 1, 'feel': 1, 'work': 1, 'church': 1, 'pay': 1})

# %%
# FreqDist 좀 더 살펴보기
frqwords.N() # 7 : 전체 단어수
frqwords['room'] # 특정단어의 빈도
frqwords.most_common() # 빈도수가 많은 순서대로 단어 출력
frqwords.most_common(3) # 빈도수가 많은 순서대로 n개 단어 출력
# Out:
# [('matrix', 1), ('room', 1), ('television', 1)]

# %% [markdown]
# ### 트럼프 연설문에서 가장 많이 언급된 10개 단어

# %%
NNO1 = []
for ns in nouns1:
    for n in ns:
        NNO1.append(n)

# %%
frqwords1 = FreqDist(NNO1)
frqwords
# Out:
# FreqDist({'matrix': 1, 'room': 1, 'television': 1, 'feel': 1, 'work': 1, 'church': 1, 'pay': 1})

# %%
# 빈도수가 많은 순서대로 n개 단어 출력
frqwords1.most_common(10)
# Out:
# [('regime', 15),
#  ('world', 13),
#  ('korea', 11),
#  ('today', 10),
#  ('nation', 9),
#  ('time', 8),
#  ('country', 8),
#  ('war', 8),
#  ('peninsula', 8),
#  ('year', 7)]

# %% [markdown]
# ### 스티브잡스 스탠포드대 졸업축사에서 가장 많이 언급된 10개 단어

# %%
NNO2 = []
for ns in nouns2:
    for n in ns:
        NNO2.append(n)

# %%
frqwords2 = FreqDist(NNO2)
frqwords
# Out:
# FreqDist({'matrix': 1, 'room': 1, 'television': 1, 'feel': 1, 'work': 1, 'church': 1, 'pay': 1})

# %%
# 빈도수가 많은 순서대로 n개 단어 출력
frqwords2.most_common(10)
# Out:
# [('life', 17),
#  ('college', 14),
#  ('apple', 9),
#  ('everything', 6),
#  ('death', 6),
#  ('way', 5),
#  ('something', 5),
#  ('company', 5),
#  ('today', 4),
#  ('course', 4)]

# %% [markdown]
# ### 워드클라우드 wordcloud
# * 문서에 사용된 단어의 중요도나 인기도를 고려해서 빈도를 산출한 후 시각적으로 늘어놓아 표시하는 시각화 유형
# * https://github.com/amueller/word_cloud
# * pip install wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# 트럼프 연설문을 워드클라우드로 시각화
wc = dict(frqwords1.most_common())
wc
# Out:
# {'regime': 15,
#  'world': 13,
#  'korea': 11,
#  'today': 10,
#  'nation': 9,
#  'time': 8,
#  'country': 8,
#  'war': 8,
#  'peninsula': 8,
#  'year': 7,
#  'peace': 7,
#  'city': 6,
#  'line': 6,
#  'life': 6,
#  'day': 6,
#  'history': 5,
#  'something': 5,
#  'dream': 5,
#  'way': 4,
#  'freedom': 4,
#  'economy': 4,
#  'strength': 4,
#  'work': 4,
#  'future': 4,
#  'destiny': 4,
#  'form': 3,
#  'half': 3,
#  'family': 3,
#  'miracle': 3,
#  'republic': 3,
#  'wealth': 3,
#  'spirit': 3,
#  'state': 3,
#  'labor': 3,
#  'kim': 3,
#  'crime': 3,
#  'death': 3,
#  'person': 3,
#  'dictatorship': 3,
#  'glory': 3,
#  'hope': 3,
#  'danger': 3,
#  'path': 3,
#  'god': 3,
#  'thank': 3,
#  'president': 2,
#  'house': 2,
#  'trade': 2,
#  'celebrate': 2,
#  'capital': 2,
#  'armistice': 2,
#  'seoul': 2,
#  'devastation': 2,
#  'earth': 2,
#  'justice': 2,
#  'f': 2,
#  'administration': 2,
#  'crisis': 2,
#  'luck': 2,
#  'promise': 2,
#  'money': 2,
#  'technology': 2,
#  'terrorism': 2,
#  'magnificent': 2,
#  'stop': 2,
#  'loyalty': 2,
#  'score': 2,
#  'tyrant': 2,
#  'torture': 2,
#  'help': 2,
#  'north': 2,
#  'control': 2,
#  'civilization': 2,
#  'oppression': 2,
#  'surveillance': 2,
#  'place': 2,
#  'cult': 2,
#  'leader': 2,
#  'heart': 2,
#  'responsibility': 2,
#  'reality': 2,
#  'conflict': 2,
#  'home': 2,
#  'man': 2,
#  'let': 2,
#  'program': 2,
#  'weakness': 2,
#  'security': 2,
#  'prosperity': 2,
#  'america': 2,
#  'message': 2,
#  'victory': 2,
#  'speaker': 1,
#  'chung': 1,
#  'privilege': 1,
#  'speak': 1,
#  'chamber': 1,
#  'melania': 1,
#  'welcome': 1,
#  'night': 1,
#  'mrs': 1,
#  'moon': 1,
#  'hospitality': 1,
#  'reception': 1,
#  'blue': 1,
#  'cooperation': 1,
#  'relationship': 1,
#  'principle': 1,
#  'fairness': 1,
#  'reciprocity': 1,
#  'visit': 1,
#  'pleasure': 1,
#  'honor': 1,
#  'create': 1,
#  'friendship': 1,
#  'alliance': 1,
#  'inchon': 1,
#  'pork': 1,
#  'chop': 1,
#  'spring': 1,
#  'price': 1,
#  'congratulate': 1,
#  'lifetime': 1,
#  'south': 1,
#  'expectancy': 1,
#  'election': 1,
#  'stock': 1,
#  'market': 1,
#  'unemployment': 1,
#  'isis': 1,
#  'court': 1,
#  'vicinity': 1,
#  'aircraft': 1,
#  'fighter': 1,
#  'addition': 1,
#  'spending': 1,
#  'equipment': 1,
#  'end': 1,
#  'anybody': 1,
#  'inspiration': 1,
#  'transformation': 1,
#  'govern': 1,
#  'restore': 1,
#  'college': 1,
#  'fact': 1,
#  'trump': 1,
#  'golf': 1,
#  'club': 1,
#  'bedminster': 1,
#  'jersey': 1,
#  'golfer': 1,
#  'sung': 1,
#  'hyun': 1,
#  'park': 1,
#  'sixty': 1,
#  'building': 1,
#  'lotte': 1,
#  'tower': 1,
#  'beautiful': 1,
#  'grace': 1,
#  'sky': 1,
#  'job': 1,
#  'rd': 1,
#  'winter': 1,
#  'grueling': 1,
#  'population': 1,
#  'pay': 1,
#  'electricity': 1,
#  'continue': 1,
#  'die': 1,
#  'hunger': 1,
#  'age': 1,
#  'percent': 1,
#  'growth': 1,
#  'malnutrition': 1,
#  'spent': 1,
#  'living': 1,
#  'allegiance': 1,
#  'starve': 1,
#  'infraction': 1,
#  'citizen': 1,
#  'picture': 1,
#  'newspaper': 1,
#  'wreck': 1,
#  'credit': 1,
#  'rank': 1,
#  'toiling': 1,
#  'starvation': 1,
#  'rape': 1,
#  'murder': 1,
#  'basis': 1,
#  'instance': 1,
#  'boy': 1,
#  'treason': 1,
#  'student': 1,
#  'school': 1,
#  'detail': 1,
#  'jong': 1,
#  'un': 1,
#  'language': 1,
#  'part': 1,
#  'christianity': 1,
#  'book': 1,
#  'kind': 1,
#  'abort': 1,
#  'woman': 1,
#  'baby': 1,
#  'father': 1,
#  'bucket': 1,
#  'deserve': 1,
#  'impure': 1,
#  'obligation': 1,
#  'horror': 1,
#  'government': 1,
#  'attempt': 1,
#  'flee': 1,
#  'think': 1,
#  'human': 1,
#  'animal': 1,
#  'realize': 1,
#  'laboratory': 1,
#  'achievement': 1,
#  'fascism': 1,
#  'result': 1,
#  'experiment': 1,
#  'gdp': 1,
#  'capita': 1,
#  'misery': 1,
#  'surprise': 1,
#  'contrast': 1,
#  'speech': 1,
#  'knowledge': 1,
#  'music': 1,
#  'possession': 1,
#  'search': 1,
#  'action': 1,
#  'society': 1,
#  'propaganda': 1,
#  'hour': 1,
#  'center': 1,
#  'rule': 1,
#  'parent': 1,
#  'protector': 1,
#  'existence': 1,
#  'proud': 1,
#  'worship': 1,
#  'build': 1,
#  'grow': 1,
#  'dictator': 1,
#  'ownership': 1,
#  'hahn': 1,
#  'landscape': 1,
#  'success': 1,
#  'cause': 1,
#  'anxiety': 1,
#  'alarm': 1,
#  'failure': 1,
#  'suffer': 1,
#  'capture': 1,
#  'plane': 1,
#  'assassinate': 1,
#  'objective': 1,
#  'spell': 1,
#  'missile': 1,
#  'defiance': 1,
#  'assurance': 1,
#  'agreement': 1,
#  'commitment': 1,
#  'plutonium': 1,
#  'deal': 1,
#  'treaty': 1,
#  'non': 1,
#  'proliferation': 1,
#  'give': 1,
#  'chance': 1,
#  'hand': 1,
#  'engagement': 1,
#  'ship': 1,
#  'japan': 1,
#  'threaten': 1,
#  'restraint': 1,
#  'miscalculation': 1,
#  'liberty': 1,
#  'applause': 1,
#  'drawn': 1,
#  'decency': 1,
#  'depravity': 1,
#  'law': 1,
#  'despair': 1,
#  'choice': 1,
#  'cost': 1,
#  'defense': 1,
#  'nazism': 1,
#  'imperialism': 1,
#  'communism': 1,
#  'confrontation': 1,
#  'resolve': 1,
#  'anyone': 1,
#  'determination': 1,
#  'doubt': 1,
#  'longer': 1,
#  'permit': 1,
#  'destruction': 1,
#  'ground': 1,
#  'secure': 1,
#  'tolerate': 1,
#  'menace': 1,
#  'rogue': 1,
#  'support': 1,
#  'supply': 1,
#  'accept': 1,
#  'china': 1,
#  'russia': 1,
#  'council': 1,
#  'sever': 1,
#  'duty': 1,
#  'confront': 1,
#  'wait': 1,
#  'threat': 1,
#  'weight': 1,
#  'conscience': 1,
#  'deliver': 1,
#  'safer': 1,
#  'grave': 1,
#  'step': 1,
#  'face': 1,
#  'grandfather': 1,
#  'hell': 1,
#  'offer': 1,
#  'aggression': 1,
#  'development': 1,
#  'denuclearization': 1,
#  'view': 1,
#  'mass': 1,
#  'discuss': 1,
#  'brighter': 1,
#  'sinister': 1,
#  'thing': 1,
#  'enjoy': 1,
#  'courage': 1,
#  'land': 1,
#  'culture': 1,
#  'community': 1,
#  'treasure': 1,
#  'sovereignty': 1,
#  'affirm': 1,
#  'dignity': 1,
#  'potential': 1,
#  'soul': 1,
#  'ambition': 1,
#  'nightmare': 1,
#  'alert': 1,
#  'bless': 1}

# %%
wcimg = WordCloud(background_color='white', width=640, height=480).generate_from_frequencies(wc)
plt.imshow(wcimg, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 639.5, 479.5, -0.5)

# %%
# 마스크를 이용한 워드 클라우드
# pip install image
# pip install pillow

# %%
pip install image
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: image in ./.local/lib/python3.7/site-packages (1.5.33)
# Requirement already satisfied: pillow in /opt/miniconda3/lib/python3.7/site-packages (from image) (8.3.2)
# Requirement already satisfied: django in ./.local/lib/python3.7/site-packages (from image) (3.2.9)
# Requirement already satisfied: six in /opt/miniconda3/lib/python3.7/site-packages (from image) (1.16.0)
# Requirement already satisfied: pytz in /opt/miniconda3/lib/python3.7/site-packages (from django->image) (2021.1)
# Requirement already satisfied: asgiref<4,>=3.3.2 in ./.local/lib/python3.7/site-packages (from django->image) (3.4.1)
# Requirement already satisfied: sqlparse>=0.2.2 in ./.local/lib/python3.7/site-packages (from django->image) (0.4.2)
# Requirement already satisfied: typing-extensions in /opt/miniconda3/lib/python3.7/site-packages (from asgiref<4,>=3.3.2->django->image) (3.10.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pillow in /opt/miniconda3/lib/python3.7/site-packages (8.3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from PIL import Image

# %%
mask_path = 'img/h.jpg'
mask = np.array(Image.open(mask_path))

# %%
wcimg = WordCloud(background_color='white', mask = mask).generate_from_frequencies(wc)
plt.figure(figsize=(10,10))
plt.imshow(wcimg, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 1199.5, 1095.5, -0.5)
